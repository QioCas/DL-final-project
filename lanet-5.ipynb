# %% [markdown]
# # Report: Final Project (Training LeNet-5 on MNIST)

# %% [markdown]
# In this report, we will train a LaNet-5 model using the MNIST dataset for
# handwritten digit recognition.

# %% [markdown]
# ## 1. Load MNIST data

# %% [markdown]
# The training dataset was split into 80% for training and 20% for validation.

# %%
import torchvision
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

transform = transforms.ToTensor()

trainset = torchvision.datasets.MNIST(root='./data', train=True, transform=transform, download=True)

lentrainset = list(range(len(trainset)))
# Split train set and test set
lentrainsubset, lenvalsubset = train_test_split(lentrainset, test_size=0.2, random_state=36)

trainsubset = torch.utils.data.Subset(trainset, lentrainsubset)
valsubset = torch.utils.data.Subset(trainset, lenvalsubset)

testset = torchvision.datasets.MNIST(root='./data', train=False, transform=transform, download=True)

trainloader = torch.utils.data.DataLoader(trainsubset, batch_size=32, shuffle=True, num_workers=2)
valloader = torch.utils.data.DataLoader(valsubset, batch_size=32, shuffle=False, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=32, shuffle=False, num_workers=2)

# %%
print(f"Train size: {len(trainsubset)}, Valid Size: {len(valsubset)}, Test size: {len(testset)}")
# Out:
# Train size: 48000, Valid Size: 12000, Test size: 10000

# %% [markdown]
# ## 2. Visualize training dataset

# %% [markdown]
# Verify the training dataset after spliting by visualization.

# %%
fig, axes = plt.subplots(6, 10, figsize=(10, 6))
j = 0

for i, ax in enumerate(axes.flat):
    image, label = trainsubset[j]
    while label != i % 10:
        j += 1
        image, label = trainsubset[j]

    ax.imshow(image[0], cmap='gray')
    ax.axis('off')

# %% [markdown]
# ## 3. Building Model

# %% [markdown]
# ### 3.1 Define Lenet5 model

# %%
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        # Convolution 1 & Pooling 1
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=9, kernel_size=3, padding=1)
        self.AvgPool1 = nn.AvgPool2d(kernel_size=2, stride=2)

        # Convolution 2 & Pooling 2
        self.conv2 = nn.Conv2d(in_channels=9, out_channels=36, kernel_size=5)
        self.AvgPool2 = nn.AvgPool2d(kernel_size=2, stride=2)

        # Convolution 3
        self.conv3 = nn.Conv2d(in_channels=36, out_channels=72, kernel_size=2)

        # Flatten
        self.Flatten = nn.Flatten()

        # Full Connected 1, 2
        self.fc1 = nn.Linear(72*4*4, 96)
        self.fc2 = nn.Linear(96, 10)

        self.tanh = nn.Tanh()


    def forward(self, x):
        x = self.tanh(self.conv1(x))
        x = self.AvgPool1(x)
        x = self.tanh(self.conv2(x))
        x = self.AvgPool2(x)
        x = self.tanh(self.conv3(x))

        x = self.Flatten(x)
        x = self.tanh(self.fc1(x))
        x = torch.softmax(self.fc2(x), dim=1)

        return x

# %% [markdown]
# ### 3.2 Define `Train_model` function

# %%
def Train_model():
    model.train()
    total_loss = 0.0

    for inputs, labels in trainloader:
        inputs, labels = inputs.to(device), labels.to(device)

        predictions = model(inputs)
        loss = loss_fn(predictions, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()


    loss = total_loss / len(trainloader)
    return loss

# %% [markdown]
# ### 3.3 Define `Valid_model` function

# %%
def Valid_model():
    model.eval()
    total_loss = 0.0
    correct_predictions = 0
    total_samples = 0

    with torch.no_grad():
        for inputs, labels in valloader:
            inputs, labels = inputs.to(device), labels.to(device)

            predictions = model(inputs)
            loss = loss_fn(predictions, labels)

            total_loss += loss.item() * inputs.size(0)

            _, predicted = torch.max(predictions, 1)
            correct_predictions += (predicted == labels).sum().item()
            total_samples += inputs.size(0)


    avg_loss = total_loss / total_samples
    accuracy = correct_predictions / total_samples

    return avg_loss, accuracy

# %% [markdown]
# ### 3.4 Define `Early_stopping` function

# %% [markdown]
# Use `Early Stopping` to halt training after the accuracy stops improving.

# %%
class Early_stopping():
    def __init__(self, patience=15, delta=0):
        self.patience = patience
        self.delta = delta

        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.best_model_state = None


    def __call__(self, val_loss, model):
        if self.best_score is None:
            self.best_score = val_loss
            self.best_model_state = model.state_dict()
        elif val_loss < self.best_score - self.delta:
            self.best_score = val_loss
            self.counter = 0
            self.best_model_state = model.state_dict()
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True


    def load_best_model(self, model):
        model.load_state_dict(self.best_model_state)

# %% [markdown]
# ## 4. Training model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LeNet5().to(device)

loss_fn = nn.CrossEntropyLoss() # loss function
optimizer = torch.optim.Adam(model.parameters(), lr=0.001) # optimizer
early_stopping = Early_stopping(patience=15, delta=0)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5)

# %%
num_epochs = 200
trainloss_list = []
valloss_list = []
valaccuracy_list = []

for epoch in range(num_epochs):

    train_loss = Train_model()
    val_loss, val_accuracy = Valid_model()

    scheduler.step(val_loss)
    early_stopping(val_loss, model)

    if early_stopping.early_stop:
        print("Early stopping")
        break

    trainloss_list.append(train_loss)
    valloss_list.append(val_loss)
    valaccuracy_list.append(val_accuracy)

    print(f"Epoch: {epoch + 1} / {num_epochs}, Average training loss: {train_loss:.9f},  Validation loss: {val_loss:.9f}, Validation accuracy: {val_accuracy:.9f}", end=', ')

    for param_group in optimizer.param_groups:
        print(f"Learning Rate = {param_group['lr']}")


early_stopping.load_best_model(model)
# Out:
# Epoch: 1 / 200, Average training loss: 1.572810981,  Validation loss: 1.520870729, Validation accuracy: 0.947500000, Learning Rate = 0.001
# Epoch: 2 / 200, Average training loss: 1.509046387,  Validation loss: 1.501507852, Validation accuracy: 0.964166667, Learning Rate = 0.001
# Epoch: 3 / 200, Average training loss: 1.495930365,  Validation loss: 1.492462856, Validation accuracy: 0.972000000, Learning Rate = 0.001
# Epoch: 4 / 200, Average training loss: 1.489053821,  Validation loss: 1.492432347, Validation accuracy: 0.971083333, Learning Rate = 0.001
# Epoch: 5 / 200, Average training loss: 1.484841074,  Validation loss: 1.485892110, Validation accuracy: 0.977750000, Learning Rate = 0.001
# Epoch: 6 / 200, Average training loss: 1.482322342,  Validation loss: 1.483953712, Validation accuracy: 0.979166667, Learning Rate = 0.001
# Epoch: 7 / 200, Average training loss: 1.481930051,  Validation loss: 1.483358314, Validation accuracy: 0.979000000, Learning Rate = 0.001
# Epoch: 8 / 200, Average training loss: 1.479158382,  Validation loss: 1.482096409, Validation accuracy: 0.981000000, Learning Rate = 0.001
# Epoch: 9 / 200, Average training loss: 1.478044264,  Validation loss: 1.483148535, Validation accuracy: 0.979416667, Learning Rate = 0.001
# Epoch: 10 / 200, Average training loss: 1.477201780,  Validation loss: 1.483066922, Validation accuracy: 0.979416667, Learning Rate = 0.001
# Epoch: 11 / 200, Average training loss: 1.476834593,  Validation loss: 1.481771054, Validation accuracy: 0.980666667, Learning Rate = 0.001
# Epoch: 12 / 200, Average training loss: 1.475630366,  Validation loss: 1.478794611, Validation accuracy: 0.983166667, Learning Rate = 0.001
# Epoch: 13 / 200, Average training loss: 1.475579804,  Validation loss: 1.480691603, Validation accuracy: 0.981666667, Learning Rate = 0.001
# Epoch: 14 / 200, Average training loss: 1.474378616,  Validation loss: 1.481710344, Validation accuracy: 0.980833333, Learning Rate = 0.001
# Epoch: 15 / 200, Average training loss: 1.474038425,  Validation loss: 1.481060955, Validation accuracy: 0.980750000, Learning Rate = 0.001
# Epoch: 16 / 200, Average training loss: 1.472892144,  Validation loss: 1.478371237, Validation accuracy: 0.983750000, Learning Rate = 0.001
# Epoch: 17 / 200, Average training loss: 1.472737320,  Validation loss: 1.479514867, Validation accuracy: 0.982333333, Learning Rate = 0.001
# Epoch: 18 / 200, Average training loss: 1.473252615,  Validation loss: 1.479434380, Validation accuracy: 0.983583333, Learning Rate = 0.001
# Epoch: 19 / 200, Average training loss: 1.472742927,  Validation loss: 1.476984170, Validation accuracy: 0.984666667, Learning Rate = 0.001
# Epoch: 20 / 200, Average training loss: 1.472410907,  Validation loss: 1.477921828, Validation accuracy: 0.984166667, Learning Rate = 0.001
# Epoch: 21 / 200, Average training loss: 1.471821455,  Validation loss: 1.479148971, Validation accuracy: 0.983166667, Learning Rate = 0.001
# Epoch: 22 / 200, Average training loss: 1.471198010,  Validation loss: 1.476229434, Validation accuracy: 0.986333333, Learning Rate = 0.001
# Epoch: 23 / 200, Average training loss: 1.470948590,  Validation loss: 1.476464136, Validation accuracy: 0.985166667, Learning Rate = 0.001
# Epoch: 24 / 200, Average training loss: 1.471008893,  Validation loss: 1.477957772, Validation accuracy: 0.983666667, Learning Rate = 0.001
# Epoch: 25 / 200, Average training loss: 1.470746866,  Validation loss: 1.479512433, Validation accuracy: 0.981750000, Learning Rate = 0.001
# Epoch: 26 / 200, Average training loss: 1.471791658,  Validation loss: 1.478555467, Validation accuracy: 0.983583333, Learning Rate = 0.001
# Epoch: 27 / 200, Average training loss: 1.470651750,  Validation loss: 1.478583330, Validation accuracy: 0.983166667, Learning Rate = 0.001
# Epoch: 28 / 200, Average training loss: 1.470897304,  Validation loss: 1.475891539, Validation accuracy: 0.986083333, Learning Rate = 0.001
# Epoch: 29 / 200, Average training loss: 1.470372354,  Validation loss: 1.476322693, Validation accuracy: 0.985750000, Learning Rate = 0.001
# Epoch: 30 / 200, Average training loss: 1.469441302,  Validation loss: 1.477239690, Validation accuracy: 0.984583333, Learning Rate = 0.001
# Epoch: 31 / 200, Average training loss: 1.470364084,  Validation loss: 1.477794593, Validation accuracy: 0.983750000, Learning Rate = 0.001
# Epoch: 32 / 200, Average training loss: 1.470210079,  Validation loss: 1.478056521, Validation accuracy: 0.983333333, Learning Rate = 0.001
# Epoch: 33 / 200, Average training loss: 1.469710104,  Validation loss: 1.477318121, Validation accuracy: 0.984750000, Learning Rate = 0.001
# Epoch: 34 / 200, Average training loss: 1.469592305,  Validation loss: 1.475151956, Validation accuracy: 0.986500000, Learning Rate = 0.001
# Epoch: 35 / 200, Average training loss: 1.468953909,  Validation loss: 1.476698961, Validation accuracy: 0.984500000, Learning Rate = 0.001
# Epoch: 36 / 200, Average training loss: 1.469146199,  Validation loss: 1.475155697, Validation accuracy: 0.986416667, Learning Rate = 0.001
# Epoch: 37 / 200, Average training loss: 1.469091849,  Validation loss: 1.476221157, Validation accuracy: 0.985666667, Learning Rate = 0.001
# Epoch: 38 / 200, Average training loss: 1.469035798,  Validation loss: 1.475574137, Validation accuracy: 0.986500000, Learning Rate = 0.001
# Epoch: 39 / 200, Average training loss: 1.468413329,  Validation loss: 1.476654792, Validation accuracy: 0.984833333, Learning Rate = 0.001
# Epoch: 40 / 200, Average training loss: 1.468254788,  Validation loss: 1.475515677, Validation accuracy: 0.986416667, Learning Rate = 0.0001
# Epoch: 41 / 200, Average training loss: 1.466669223,  Validation loss: 1.474336910, Validation accuracy: 0.987250000, Learning Rate = 0.0001
# Epoch: 42 / 200, Average training loss: 1.465372110,  Validation loss: 1.474299059, Validation accuracy: 0.986916667, Learning Rate = 0.0001
# Epoch: 43 / 200, Average training loss: 1.464576424,  Validation loss: 1.473911075, Validation accuracy: 0.987750000, Learning Rate = 0.0001
# Epoch: 44 / 200, Average training loss: 1.464237334,  Validation loss: 1.473875771, Validation accuracy: 0.987166667, Learning Rate = 0.0001
# Epoch: 45 / 200, Average training loss: 1.464002295,  Validation loss: 1.473676351, Validation accuracy: 0.987833333, Learning Rate = 0.0001
# Epoch: 46 / 200, Average training loss: 1.463808474,  Validation loss: 1.473664364, Validation accuracy: 0.988250000, Learning Rate = 0.0001
# Epoch: 47 / 200, Average training loss: 1.463677280,  Validation loss: 1.473464265, Validation accuracy: 0.987833333, Learning Rate = 0.0001
# Epoch: 48 / 200, Average training loss: 1.463543459,  Validation loss: 1.473734106, Validation accuracy: 0.987416667, Learning Rate = 0.0001
# Epoch: 49 / 200, Average training loss: 1.463396175,  Validation loss: 1.473501978, Validation accuracy: 0.988166667, Learning Rate = 0.0001
# Epoch: 50 / 200, Average training loss: 1.463302652,  Validation loss: 1.473738651, Validation accuracy: 0.988166667, Learning Rate = 0.0001
# Epoch: 51 / 200, Average training loss: 1.463258301,  Validation loss: 1.473575323, Validation accuracy: 0.988250000, Learning Rate = 0.0001
# Epoch: 52 / 200, Average training loss: 1.463206354,  Validation loss: 1.473277982, Validation accuracy: 0.988333333, Learning Rate = 0.0001
# Epoch: 53 / 200, Average training loss: 1.463119752,  Validation loss: 1.473240401, Validation accuracy: 0.988250000, Learning Rate = 0.0001
# Epoch: 54 / 200, Average training loss: 1.463084798,  Validation loss: 1.473171074, Validation accuracy: 0.988416667, Learning Rate = 0.0001
# Epoch: 55 / 200, Average training loss: 1.463049165,  Validation loss: 1.472828723, Validation accuracy: 0.988833333, Learning Rate = 0.0001
# Epoch: 56 / 200, Average training loss: 1.463004988,  Validation loss: 1.473343391, Validation accuracy: 0.987916667, Learning Rate = 0.0001
# Epoch: 57 / 200, Average training loss: 1.462967695,  Validation loss: 1.473255373, Validation accuracy: 0.988166667, Learning Rate = 0.0001
# Epoch: 58 / 200, Average training loss: 1.462928512,  Validation loss: 1.473073887, Validation accuracy: 0.988166667, Learning Rate = 0.0001
# Epoch: 59 / 200, Average training loss: 1.462916711,  Validation loss: 1.473259602, Validation accuracy: 0.987666667, Learning Rate = 0.0001
# Epoch: 60 / 200, Average training loss: 1.462876837,  Validation loss: 1.473240092, Validation accuracy: 0.988250000, Learning Rate = 0.0001
# Epoch: 61 / 200, Average training loss: 1.462852125,  Validation loss: 1.473611550, Validation accuracy: 0.987666667, Learning Rate = 1e-05
# Epoch: 62 / 200, Average training loss: 1.462818937,  Validation loss: 1.473475831, Validation accuracy: 0.987833333, Learning Rate = 1e-05
# Epoch: 63 / 200, Average training loss: 1.462814477,  Validation loss: 1.473369191, Validation accuracy: 0.987833333, Learning Rate = 1e-05
# Epoch: 64 / 200, Average training loss: 1.462811764,  Validation loss: 1.473348308, Validation accuracy: 0.988000000, Learning Rate = 1e-05
# Epoch: 65 / 200, Average training loss: 1.462809189,  Validation loss: 1.473267701, Validation accuracy: 0.988166667, Learning Rate = 1e-05
# Epoch: 66 / 200, Average training loss: 1.462804632,  Validation loss: 1.473266726, Validation accuracy: 0.988083333, Learning Rate = 1e-05
# Epoch: 67 / 200, Average training loss: 1.462799307,  Validation loss: 1.473216068, Validation accuracy: 0.988250000, Learning Rate = 1.0000000000000002e-06
# Epoch: 68 / 200, Average training loss: 1.462794066,  Validation loss: 1.473210296, Validation accuracy: 0.988250000, Learning Rate = 1.0000000000000002e-06
# Epoch: 69 / 200, Average training loss: 1.462793206,  Validation loss: 1.473204537, Validation accuracy: 0.988500000, Learning Rate = 1.0000000000000002e-06
# Early stopping
# Done training

# %% [markdown]
# ## 5. Evaluating model

# %% [markdown]
# ### 5.1 Define `Evaludate_model` function

# %%
def Evaludate_model():
    model.eval()
    correct = 0
    total = 0

    output_labels = np.array([])
    predict_labels = np.array([])


    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)

            predictions = model(inputs)
            _, predicted = torch.max(predictions, 1)

            total += labels.size(0)

            correct += (predicted == labels).sum().item()

            output_labels = np.append(output_labels, labels.cpu().numpy())
            predict_labels = np.append(predict_labels, predicted.cpu().numpy())


    return correct / total, output_labels, predict_labels

# %% [markdown]
# ### 5.2 Define Confustion Matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay

from sklearn.metrics import confusion_matrix, classification_report

def cm_plot(y_test, y_pred):
    confuse_matrix = confusion_matrix(y_test, y_pred)
    display = ConfusionMatrixDisplay(confusion_matrix=confuse_matrix)
    display.plot()

# %%
accuracy, output_label, predict_label = Evaludate_model()

print(f"Accuracy on test set: {accuracy * 100:.2f}%")

report = classification_report(output_label, predict_label, target_names=["number " + str(i) for i in range(10)])
print('Classification report:\n', report)

cm_plot(output_label, predict_label)
# Out:
# Accuracy on test set: 98.89%
# Classification report:
#                precision    recall  f1-score   support
#
#     number 0       1.00      0.99      0.99       980
#     number 1       0.99      1.00      0.99      1135
#     number 2       0.99      0.99      0.99      1032
#     number 3       0.99      0.99      0.99      1010
#     number 4       0.99      0.98      0.99       982
#     number 5       0.99      0.99      0.99       892
#     number 6       0.99      0.99      0.99       958
#     number 7       0.98      0.98      0.98      1028
#     number 8       0.99      0.99      0.99       974
#     number 9       0.98      0.99      0.98      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %% [markdown]
# ### 5.3 Plot charts

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Plot Loss
axes[0].plot(trainloss_list, label='Training loss', color='blue')
axes[0].plot(valloss_list, label='Validation loss', color='green')
axes[0].set(xlabel='Epoch', ylabel='Loss', title='Loss: Training vs Validation')
axes[0].legend()

# Plot Accuracy
axes[1].plot(valaccuracy_list, label='Validation accuracy', color='red')
axes[1].set(xlabel='Epoch', ylabel='Accuracy', title='Validation Accuracy')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# The model achieved an impressive accuracy of 98.89%. Beside, by implementing early stopping, we successfully prevented overfitting, ensuring the model generalizes well to unseen data.
